# %%
#importing all the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv('MatNavi Mechanical properties of low-alloy steels.csv')

# %%
Data.head()
# Out:
#   Alloy code     C    Si    Mn      P      S     Ni    Cr    Mo    Cu    V  \
# 0        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
# 1        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
# 2        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
# 3        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
# 4        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
#
#       Al       N  Ceq  Nb + Ta   Temperature (°C)   0.2% Proof Stress (MPa)  \
# 0  0.003  0.0066  0.0      0.0                 27                       342
# 1  0.003  0.0066  0.0      0.0                100                       338
# 2  0.003  0.0066  0.0      0.0                200                       337
# 3  0.003  0.0066  0.0      0.0                300                       346
# 4  0.003  0.0066  0.0      0.0                400                       316
#
# ...

# %%
print(Data.shape)
# Out:
# (915, 20)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Alloy code                915 non-null    object
#  1    C                        915 non-null    float64
#  2    Si                       915 non-null    float64
#  3    Mn                       915 non-null    float64
#  4    P                        915 non-null    float64
#  5    S                        915 non-null    float64
#  6    Ni                       915 non-null    float64
#  7    Cr                       915 non-null    float64
#  8    Mo                       915 non-null    float64
#  9    Cu                       915 non-null    float64
#  10  V                         915 non-null    float64
#  11   Al                       915 non-null    float64
#  12   N                        915 non-null    float64
# ...

# %%
Data.describe()
# Out:
#                 C          Si          Mn           P           S          Ni  \
# count  915.000000  915.000000  915.000000  915.000000  915.000000  915.000000
# mean     0.174929    0.310918    0.812962    0.014543    0.010602    0.143016
# std      0.059674    0.086871    0.342775    0.005244    0.004024    0.172746
# min      0.090000    0.180000    0.420000    0.006000    0.003000    0.000000
# 25%      0.130000    0.240000    0.500000    0.010000    0.008000    0.023000
# 50%      0.160000    0.300000    0.680000    0.014000    0.010000    0.050000
# 75%      0.200000    0.370000    1.210000    0.018000    0.012000    0.210000
# max      0.340000    0.520000    1.480000    0.030000    0.022000    0.600000
#
#                Cr          Mo          Cu           V          Al           N  \
# count  915.000000  915.000000  915.000000  915.000000  915.000000  915.000000
# mean     0.427861    0.442870    0.079148    0.060190    0.012435    0.007652
# ...

# %%
Data.isnull()
# Out:
#      Alloy code      C     Si     Mn      P      S     Ni     Cr     Mo  \
# 0         False  False  False  False  False  False  False  False  False
# 1         False  False  False  False  False  False  False  False  False
# 2         False  False  False  False  False  False  False  False  False
# 3         False  False  False  False  False  False  False  False  False
# 4         False  False  False  False  False  False  False  False  False
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 910       False  False  False  False  False  False  False  False  False
# 911       False  False  False  False  False  False  False  False  False
# 912       False  False  False  False  False  False  False  False  False
# 913       False  False  False  False  False  False  False  False  False
# 914       False  False  False  False  False  False  False  False  False
#
#         Cu      V     Al      N    Ceq  Nb + Ta   Temperature (°C)  \
# ...

# %%
#tensile strenght as target variable

plt.figure(figsize=(8,6))
sns.histplot(Data[' Tensile Strength (MPa)'], bins = 25)
plt.title('Tensile Stength Distribution')
plt.xlabel('Material Tensile Strength (MPa)')
plt.ylabel('Number of readings')
plt.show()

# %%
print(Data.columns)
# Out:
# Index(['Alloy code', ' C', ' Si', ' Mn', ' P', ' S', ' Ni', ' Cr', ' Mo',
#        ' Cu', 'V', ' Al', ' N', 'Ceq', 'Nb + Ta', ' Temperature (°C)',
#        ' 0.2% Proof Stress (MPa)', ' Tensile Strength (MPa)',
#        ' Elongation (%)', ' Reduction in Area (%)'],
#       dtype='object')

# %%
Data.columns = Data.columns.str.strip()
print(Data.columns)
# Out:
# Index(['Alloy code', 'C', 'Si', 'Mn', 'P', 'S', 'Ni', 'Cr', 'Mo', 'Cu', 'V',
#        'Al', 'N', 'Ceq', 'Nb + Ta', 'Temperature (°C)',
#        '0.2% Proof Stress (MPa)', 'Tensile Strength (MPa)', 'Elongation (%)',
#        'Reduction in Area (%)'],
#       dtype='object')

# %%
#variation with composition

composition_of_elements = ['C',	'Si',	'Mn',	'P',	'S',	'Ni',	'Cr',	'Mo',	'Cu',	'V',	'Al',	'N',	'Ceq',	'Nb + Ta','Temperature (°C)']
correlation = Data[composition_of_elements+['Tensile Strength (MPa)']].corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, annot=True, center=0, cmap='coolwarm')
plt.title('Tensile Strength correlation with Elements')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,5))
sns.scatterplot(x='C', y='Tensile Strength (MPa)', data=Data, ax=axes[0])
axes[0].set_title('Carbon % vs Tensile Strength')

sns.scatterplot(x='Ceq', y='Tensile Strength (MPa)', data=Data, ax=axes[1])
axes[1].set_title('Carbon Equivalent vs Tensile Strength')
plt.show()

# %%
#checking different temprature for a given alloy

print(Data.groupby('Alloy code')['Temperature (°C)'].nunique().describe())
# Out:
# count    95.000000
# mean      9.631579
# std       0.546802
# min       9.000000
# 25%       9.000000
# 50%      10.000000
# 75%      10.000000
# max      11.000000
# Name: Temperature (°C), dtype: float64

# %%
#histogram to see properties relation with element composition

target_columns = ['0.2% Proof Stress (MPa)', 'Tensile Strength (MPa)', 'Elongation (%)',
       'Reduction in Area (%)']
fig, axes = plt.subplots(2,2, figsize = (12,10))
axes = axes.flatten()

for i, col in enumerate(target_columns):
    sns.histplot(Data[col], kde = True, bins=30, ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')

plt.show()

# %%
#scatter plot of composition of elemets with tensile strength

composition_cols = ['C', 'Si', 'Mn', 'P', 'S', 'Ni', 'Cr', 'Mo', 'Cu', 'V',
       'Al', 'N', 'Ceq', 'Nb + Ta','Temperature (°C)']
fig,axes = plt.subplots(4,4, figsize=(18,20))
axes = axes.flatten()

for i,col in enumerate(composition_cols):
    sns.scatterplot(x=Data[col], y=Data['Tensile Strength (MPa)'], ax=axes[i])
    axes[i].set_title(f'{col} vs Tensile Strength')

plt.show()

# %%
Data[Data['Tensile Strength (MPa)'] == Data['Tensile Strength (MPa)'].max()]
# Out:
#     Alloy code     C    Si    Mn      P      S   Ni    Cr    Mo    Cu    V  \
# 626        VbF  0.18  0.37  0.66  0.018  0.017  0.1  1.07  1.03  0.12  0.3
#
#        Al       N  Ceq  Nb + Ta  Temperature (°C)  0.2% Proof Stress (MPa)  \
# 626  0.02  0.0081  0.0      0.0               300                      519
#
#      Tensile Strength (MPa)  Elongation (%)  Reduction in Area (%)
# 626                    6661              11                     28

# %%
Data.nlargest(5, 'Tensile Strength (MPa)')
# Out:
#     Alloy code     C    Si    Mn      P      S    Ni    Cr    Mo    Cu     V  \
# 626        VbF  0.18  0.37  0.66  0.018  0.017  0.10  1.07  1.03  0.12  0.30
# 391        VaC  0.29  0.20  0.75  0.010  0.009  0.34  1.00  1.25  0.14  0.26
# 421        VaG  0.29  0.26  0.76  0.009  0.007  0.45  1.12  1.18  0.07  0.23
# 431        VaH  0.29  0.26  0.77  0.009  0.007  0.46  1.12  1.20  0.08  0.23
# 371        VaA  0.28  0.20  0.72  0.015  0.012  0.32  1.02  1.12  0.20  0.27
#
#         Al       N  Ceq  Nb + Ta  Temperature (°C)  0.2% Proof Stress (MPa)  \
# 626  0.020  0.0081  0.0      0.0               300                      519
# 391  0.002  0.0075  0.0      0.0                27                      690
# 421  0.003  0.0103  0.0      0.0                27                      685
# 431  0.004  0.0095  0.0      0.0                27                      660
# 371  0.002  0.0075  0.0      0.0                27                      655
#
# ...

# %%
#data split using group shuffle split
from sklearn.model_selection import GroupShuffleSplit

group_shuffle_shift =  GroupShuffleSplit(n_splits= 1, test_size=0.25, random_state=42)
train_index, test_index = next(group_shuffle_shift.split(Data, groups=Data['Alloy code']))

train_Data = Data.iloc[train_index]
test_Data = Data.iloc[test_index]

# %%
# !pip install statsmodels

# %%
#checking multicollinearity using VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

x = Data[composition_cols].copy()

vif_data =  pd.DataFrame()
vif_data['Feature'] = x.columns
vif_data['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif_data =  vif_data.sort_values('VIF', ascending=False)
print(vif_data)
# Out:
#              Feature        VIF
# 2                 Mn  46.644510
# 1                 Si  21.337861
# 7                 Mo  20.346065
# 0                  C  16.022344
# 3                  P  15.946497
# 11                 N  15.570167
# 6                 Cr  10.721596
# 10                Al   9.491770
# 12               Ceq   8.861808
# 4                  S   8.204924
# 8                 Cu   7.913514
# 5                 Ni   5.948297
# 9                  V   5.102014
# 14  Temperature (°C)   4.422788
# 13           Nb + Ta   2.165348

# %%
#data shows high multicollinearity
#using ridge regression

feature_col = ['C', 'Si', 'Mn', 'P', 'S', 'Ni', 'Cr', 'Mo', 'Cu', 'V',
       'Al', 'N', 'Nb + Ta','Temperature (°C)']
#excluding ceq because it is derived using formula

x_train =  train_Data[feature_col]
y_train =  train_Data['Tensile Strength (MPa)']

x_test = test_Data[feature_col]
y_test = test_Data['Tensile Strength (MPa)']

# %%
#scaling data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled =  scaler.fit_transform(x_train)
x_test_scaled =  scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

ridge= Ridge(alpha=1.0, random_state=42)
ridge.fit(x_train_scaled, y_train)
ridge_predict = ridge.predict(x_test_scaled)

print("MAE is ", mean_absolute_error(y_test, ridge_predict))
print("RMSE is ", np.sqrt(mean_squared_error(y_test, ridge_predict)))
print("r2 score is ", r2_score(y_test, ridge_predict))
# Out:
# MAE is  64.41023656071313
# RMSE is  78.5989875050743
# r2 score is  0.6302732499418222

# %%
#random forest regresion

from sklearn.ensemble import RandomForestRegressor

random_forest =  RandomForestRegressor(n_estimators=200, random_state=42)
random_forest.fit(x_train,y_train)
random_forest_predict = random_forest.predict(x_test)

print("MAE is ", mean_absolute_error(y_test, random_forest_predict))
print("RMSE is ", np.sqrt(mean_squared_error(y_test, random_forest_predict)))
print("r2 score is ", r2_score(y_test, random_forest_predict))
# Out:
# MAE is  21.50914847161572
# RMSE is  30.84929554269188
# r2 score is  0.9430442634554711

# %%
# !pip install xgboost

# %%
#XGBoost regression

from xgboost import XGBRegressor

xgb = XGBRegressor(n_estimators=200, random_state=42)
xgb.fit(x_train, y_train)
xgb_predict = xgb.predict(x_test)

print("MAE is ", mean_absolute_error(y_test, xgb_predict))
print("RMSE is ", np.sqrt(mean_squared_error(y_test, xgb_predict)))
print("r2 score is ", r2_score(y_test, xgb_predict))
# Out:
# MAE is  21.444087982177734
# RMSE is  29.888175580834325
# r2 score is  0.9465379118919373

# %%
#comparison table

comparison = pd.DataFrame({
    'Model' : ['ridge regression', 'random forest', 'XGboost'],
    'MAE' : [64.41023656071313, 21.50914847161572, 21.444087982177734],
    'RMSE': [78.5989875050743, 30.84929554269188, 29.888175580834325],
    'R2': [ 0.6302732499418222, 0.9430442634554711, 0.9465379118919373]
})

comparison = comparison.sort_values('R2', ascending=False).reset_index(drop=True)
comparison
# Out:
#               Model        MAE       RMSE        R2
# 0           XGboost  21.444088  29.888176  0.946538
# 1     random forest  21.509148  30.849296  0.943044
# 2  ridge regression  64.410237  78.598988  0.630273

# %%
# !pip install shap --quiet
import shap

# %%
# !pip install --upgrade xgboost shap
# Out:
# ...
#   Using cached xgboost-3.2.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
# Using cached xgboost-3.2.0-py3-none-win_amd64.whl (101.7 MB)
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.4
#     Uninstalling xgboost-2.1.4:
#       Successfully uninstalled xgboost-2.1.4
# ...

# %%
# !pip install -U shap

# %%
# !pip install "xgboost<3.0"
# Out:
# ...
#   Using cached xgboost-2.1.4-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
# Using cached xgboost-2.1.4-py3-none-win_amd64.whl (124.9 MB)
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.2.0
#     Uninstalling xgboost-3.2.0:
#       Successfully uninstalled xgboost-3.2.0
# ...

# %%
explainer =  shap.TreeExplainer(xgb)
shap_values = explainer.shap_values(x_test)

# %%
shap.summary_plot(shap_values, x_test)

# %%
shap.summary_plot(shap_values, x_test, plot_type='bar')

# %%
shap.dependence_plot('V', shap_values, x_test)

# %%
shap.dependence_plot('Mn', shap_values, x_test)

# %%
shap.dependence_plot('Mo', shap_values, x_test)

# %%
shap.dependence_plot('C', shap_values, x_test)

# %%
import joblib

booster = xgb.get_booster()
if 'save_config' in booster.__dict__:
    del booster.__dict__['save_config']

joblib.dump(xgb, 'xgb.pkl')
# Out:
# ['xgb.pkl']
